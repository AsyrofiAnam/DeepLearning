# %% [markdown]
# <a href="https://colab.research.google.com/github/AsyrofiAnam/DeepLearning/blob/main/Klasifikasi_Gambar_Multilabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Library

# %%
# Standard Library
import os
# Data Science Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, multilabel_confusion_matrix, ConfusionMatrixDisplay
# Progress Bar
from tqdm import tqdm
# TensorFlow and Keras (Unified)
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dense, Dropout, Flatten, Conv2D, MaxPooling2D,
                                     BatchNormalization, GlobalAveragePooling2D, Input)
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import AUC
from matplotlib.pyplot import imshow
from PIL import Image

# %% [markdown]
# #Instalasi dan Setup API Kaggle

# %%
# !pip install -q kaggle

# %%
os.environ["KAGGLE_USERNAME"] = "fiin28"
os.environ["KAGGLE_KEY"] = "70a3c7c49b76b5262b742d519723ea8a"

# %% [markdown]
# #Download dan Ekstraksi Dataset dari Kaggle

# %%
# !kaggle datasets download -d fiin28/datasetmultilabe-asyrofianam-202255202070
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fiin28/datasetmultilabe-asyrofianam-202255202070
# License(s): unknown

# %%
# !unzip datasetmultilabe-asyrofianam-202255202070.zip
# Out:
# Archive:  datasetmultilabe-asyrofianam-202255202070.zip
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar001.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar002.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar003.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar004.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar005.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar006.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar007.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar008.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar009.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar010.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar011.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar012.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar013.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar014.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar015.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar016.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar017.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar018.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar019.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar020.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar021.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar022.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar023.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar024.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar025.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar026.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar027.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar028.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar029.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar030.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar031.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar032.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar033.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar034.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar035.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar036.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar037.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar038.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar039.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar040.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar041.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar042.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar043.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar044.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar045.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar046.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar047.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar048.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar049.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar050.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar051.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar052.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar053.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar054.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar055.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar056.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar057.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar058.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar059.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar060.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar061.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar062.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar063.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar064.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar065.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar066.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar067.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar068.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar069.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar070.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar071.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar072.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar073.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar074.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar075.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar076.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar077.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar078.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar079.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar080.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar081.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar082.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar083.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar084.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar085.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar086.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar087.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar088.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar089.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar090.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar091.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar092.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar093.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar094.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar095.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar096.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar097.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar098.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar099.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar100.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar101.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar102.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar103.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar104.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar105.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar106.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar107.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar108.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar109.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar110.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar111.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar112.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar113.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar114.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar115.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar116.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar117.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar118.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar119.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar120.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar121.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar122.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar123.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar124.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar125.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar126.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar127.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar128.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar129.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar130.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar131.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar132.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar133.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar134.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar135.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar136.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar137.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar138.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar139.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar140.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar141.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar142.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar143.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar144.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar145.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar146.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar147.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar148.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar149.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar150.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar151.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar152.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar153.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar154.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar155.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar156.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar157.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar158.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar159.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar160.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar161.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar162.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar163.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar164.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar165.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar166.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar167.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar168.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar169.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar170.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar171.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar172.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar173.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar174.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar175.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar176.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar177.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar178.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar179.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar180.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar181.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar182.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar183.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar184.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar185.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar186.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar187.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar188.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar189.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar190.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar191.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar192.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar193.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar194.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar195.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar196.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar197.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar198.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar199.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar200.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar201.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar202.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar203.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar204.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar205.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar206.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar207.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar208.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar209.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar210.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar211.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar212.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar213.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar214.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar215.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar216.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar217.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar218.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar219.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar220.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar221.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar222.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar223.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar224.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar225.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar226.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar227.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar228.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar229.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar230.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar231.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar232.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar233.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar234.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar235.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar236.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar237.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar238.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar239.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar240.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar241.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar242.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar243.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar244.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar245.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar246.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar247.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar248.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar249.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar250.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar251.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar252.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar253.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar254.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar255.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar256.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar257.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar258.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar259.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar260.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar261.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar262.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar263.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar264.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar265.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar266.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar267.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar268.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar269.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar270.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar271.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar272.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar273.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar274.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar275.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar276.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar277.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar278.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar279.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar280.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar281.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar282.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar283.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar284.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar285.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar286.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar287.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar288.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar289.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar290.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar291.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar292.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar293.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar294.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar295.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar296.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar297.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar298.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar299.jpg
#   inflating: DatasetMultilabe_AsyrofiAnam_202255202070/Gambar300.jpg
#   inflating: traindataset_AsyrofiAnam_202255202070.csv

# %% [markdown]
# #Load CSV dan Tampilkan Data Awal

# %%
df = pd.read_csv('/content/traindataset_AsyrofiAnam_202255202070.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           Id                                          Object  Pensil  \
# 0  Gambar001                         ['Penghapus', 'Jangka']       0
# 1  Gambar002                            ['Pensil', 'Jangka']       1
# 2  Gambar003  ['Pensil', 'Penghapus', 'Penggaris', 'Jangka']       1
# 3  Gambar004  ['Pensil', 'Penghapus', 'Penggaris', 'Jangka']       1
# 4  Gambar005            ['Pensil', 'Penghapus', 'Penggaris']       1
#
#    Penghapus  Penggaris  Jangka
# 0          1          0       1
# 1          0          0       1
# 2          1          1       1
# 3          1          1       1
# 4          1          1       0

# %% [markdown]
# #Load dan Preprocessing Gambar

# %%
SIZE = 256
X_dataset = []
image_directory = '/content/DatasetMultilabe_AsyrofiAnam_202255202070'
for i in tqdm(range(df.shape[0])):
    img = image.load_img(image_directory + '/' + df['Id'][i]+'.jpg', target_size=(SIZE,SIZE,3))
    img = image.img_to_array(img)
    img = img/255.0
    X_dataset.append(img)

X = np.array(X_dataset)
# Out:
# 100%|██████████| 300/300 [00:35<00:00,  8.52it/s]

# %%
print(df['Id'][149])
print(df['Object'][149])
image_path = os.path.join(image_directory, df['Id'][149] + '.jpg')
img = Image.open(image_path)

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.title(f"Label: {df['Object'][149]}")
plt.axis('off')
plt.show()
# Out:
# Gambar150
# ['Pensil', 'Penghapus', 'Jangka']

# %% [markdown]
# #Ekstraksi Label dan Pembagian Dataset

# %%
y = np.array(df.drop(['Id', 'Object'], axis=1))

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.10, random_state=20)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.1111, random_state=20)

print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")
# Out:
# Train: 240, Val: 30, Test: 30

# %% [markdown]
# #Arsitektur dan Kompilasi Model MobileNetV2

# %%
input_shape = (256, 256, 3)
num_classes = 4
multi_label = True

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=input_shape)

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

if multi_label:
    output = Dense(num_classes, activation='sigmoid')(x)
    loss_fn = 'binary_crossentropy'
else:
    output = Dense(num_classes, activation='softmax')(x)
    loss_fn = 'categorical_crossentropy'

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - auc: 0.9993 - loss: 0.0320 - val_auc: 0.9713 - val_loss: 0.1749
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - auc: 0.9991 - loss: 0.0329 - val_auc: 0.9813 - val_loss: 0.1507
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - auc: 1.0000 - loss: 0.0217 - val_auc: 0.9828 - val_loss: 0.1463
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - auc: 0.9999 - loss: 0.0239 - val_auc: 0.9801 - val_loss: 0.1716
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - auc: 0.9998 - loss: 0.0279 - val_auc: 0.9676 - val_loss: 0.1821
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - auc: 1.0000 - loss: 0.0157 - val_auc: 0.9775 - val_loss: 0.1738
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - auc: 1.0000 - loss: 0.0213 - val_auc: 0.9699 - val_loss: 0.1719
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - auc: 0.9996 - loss: 0.0298 - val_auc: 0.9782 - val_loss: 0.1809
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - auc: 0.9999 - loss: 0.0181 - val_auc: 0.9790 - val_loss: 0.1854

# %% [markdown]
# #Visualisasi AUC dan Loss Selama Pelatihan

# %%
# Ambil data dari history untuk plotting
auc = history.history['auc']
val_auc = history.history['val_auc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(auc))

# Plot AUC
plt.figure(figsize=(6, 4))
plt.plot(epochs, auc, 'b', label='Training AUC')
plt.plot(epochs, val_auc, 'r', label='Validation AUC')
plt.title('Training and Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot Loss
plt.figure(figsize=(6, 4))
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Prediksi Gambar Tunggal

# %%
img = image.load_img('/content/DatasetMultilabe_AsyrofiAnam_202255202070/Gambar295.jpg', target_size=(SIZE,SIZE,3))

img = image.img_to_array(img)
img = img/255.
plt.imshow(img)
img = np.expand_dims(img, axis=0)

classes = np.array(df.columns[2:])
proba = model.predict(img)
sorted_categories = np.argsort(proba[0])[:-11:-1]

for i in range(4):
    print("{}".format(classes[sorted_categories[i]])+" ({:.3})".format(proba[0][sorted_categories[i]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Penghapus (0.999)
# Jangka (0.998)
# Pensil (0.000921)
# Penggaris (0.000798)

# %% [markdown]
# #Evaluasi Model pada Data Test

# %%
loss, auc_score = model.evaluate(X_test, y_test)
print("AUC = ", (auc_score * 100.0), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - auc: 0.9783 - loss: 0.2144
# AUC =  97.826087474823 %

# %% [markdown]
# #Evaluasi Kinerja dan Confusion Matrix

# %%
# Prediksi
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Laporan klasifikas
print(classification_report(y_test, y_pred_classes, target_names=df.columns[2:], zero_division=0))

# Plot Confusion Matrix untuk setiap label
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

for i, label in enumerate(df.columns[2:]):
    cm = multilabel_confusion_matrix(y_test, y_pred_classes)[i]
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[f'Not {label}', label])
    disp.plot(ax=axes[i], values_format='d', cmap='Blues')
    axes[i].set_title(f'Confusion Matrix: {label}')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#               precision    recall  f1-score   support
#
#       Pensil       0.88      0.96      0.92        23
#    Penghapus       0.85      1.00      0.92        23
#    Penggaris       0.95      1.00      0.97        19
#       Jangka       0.96      1.00      0.98        23
#
#    micro avg       0.91      0.99      0.95        88
#    macro avg       0.91      0.99      0.95        88
# weighted avg       0.91      0.99      0.95        88
#  samples avg       0.91      0.98      0.94        88

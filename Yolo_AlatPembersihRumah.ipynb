# %% [markdown]
# <a href="https://colab.research.google.com/github/AsyrofiAnam/DeepLearning/blob/main/Yolo_AlatPembersihRumah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %%
from ultralytics import YOLO

# model YOLOv8n
model = YOLO("yolov8n.pt")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QW5yaebJDunZp2I0xvHE")
project = rf.workspace("tugas-4-deep-learning").project("alatpembersihrumah")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to AlatPembersihRumah-6 in yolov8:: 100%|██████████| 2652/2652 [00:00<00:00, 4962.65it/s]

# %%
# Training
# !yolo task=detect mode=train model=yolov8n.pt data=/content/AlatPembersihRumah-6/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/content/runs/detect/train2/confusion_matrix.png"
img = Image.open(img_path)

w, h = img.size
dpi = 100

plt.figure(figsize=(w/dpi, h/dpi), dpi=dpi)
plt.imshow(img)
plt.axis('off')
plt.title("Confusion Matrix", fontsize=12)
plt.show()

# %%
pred = Image.open("runs/detect/train2/val_batch0_pred.jpg")
labels = Image.open("runs/detect/train2/val_batch0_labels.jpg")

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(pred)
plt.axis('off')
plt.title("Predicted")

plt.subplot(1, 2, 2)
plt.imshow(labels)
plt.axis('off')
plt.title("Ground Truth")

plt.show()

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")  # model hasil training

# Prediksi 10 gambar
results_img = model.predict(source="/content/drive/MyDrive/test_images", save=True, verbose=False)

# Prediksi video
results_vid = model.predict(source="/content/drive/MyDrive/test_video.mp4", save=True, verbose=False)
# Out:
# Results saved to runs/detect/predict
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# Results saved to runs/detect/predict

# %%
import glob

predicted_images = glob.glob("runs/detect/predict/*.jpg")

plt.figure(figsize=(15, 10))
for i, img_path in enumerate(predicted_images[:10]):
    img = Image.open(img_path)
    plt.subplot(2, 5, i+1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted {i+1}")
plt.tight_layout()
plt.show()

# %%
from IPython.display import HTML
from base64 import b64encode

# download video dari url berikut
video_url = "https://github.com/AsyrofiAnam/DeepLearning/raw/refs/heads/main/test_video.mp4"

HTML(f"""
<video width="640" height="480" controls>
  <source src="{video_url}" type="video/mp4">
</video>
""")
# Out:
# <video width="640" height="480" controls>
#   <source src="https://github.com/AsyrofiAnam/DeepLearning/raw/refs/heads/main/test_video.mp4" type="video/mp4">
# </video>
